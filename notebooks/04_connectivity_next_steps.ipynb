# %% [markdown]
# # Fish2 Raphe — connectivity and functional integration
#
# Scaffold for the next analysis layer after morphology clustering.
#
# Planned outputs:
#
# 1. per-neuron input/output partner tables;
# 2. cluster-to-cluster connectivity matrices;
# 3. ROI-resolved input/output summaries;
# 4. annotation/transmitter metadata;
# 5. functional-data overlays;
# 6. comparison of morphology-defined and connectivity-defined groups.

# %%
# ============================================================
# 1. Imports + client
# ============================================================

from pathlib import Path
import sys
import pandas as pd
import numpy as np

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT / "src") not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / "src"))

from fish2_raphe.config import load_config
from fish2_raphe.neuprint_tools import make_client

CFG = load_config(PROJECT_ROOT / "configs" / "default.yaml")
c = make_client(CFG["neuprint"]["server"], CFG["neuprint"]["dataset"])
print(c)

# %%
# ============================================================
# 2. Load active morphology assignments
# ============================================================
# Point this to the active assignment table saved by the consolidated workflow.

ASSIGNMENT_CSV = (
    PROJECT_ROOT / "outputs" / "recluster_sweeps" /
    "raphe_superior_soma_in_roi" / "assignments_complete_k12.csv"
)

assignments = pd.read_csv(ASSIGNMENT_CSV)
assignments["bodyId"] = assignments["bodyId"].astype(int)
assignments["cluster"] = assignments["cluster"].astype(int)

display(assignments.head())

# %%
# ============================================================
# 3. TODO: fetch direct input/output connectivity
# ============================================================
# Candidate analyses:
#   - fetch_adjacencies for all active body IDs
#   - top input/output partners per neuron
#   - aggregate partner weights by morphology cluster
#   - restrict/summarize by ROI
#
# We will implement this next after validating the active morphology solution.
